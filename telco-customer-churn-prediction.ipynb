# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


import warnings
warnings.filterwarnings('ignore')
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
data=pd.read_csv(r'/kaggle/input/telco-customer-churn/WA_Fn-UseC_-Telco-Customer-Churn.csv')
pd.reset_option('display.max_columns',None)

# %% [markdown]
# #  Data Analysis and Preprocessing

# %%
# Display the first few rows of the dataset
print("Head of the dataset:")
data.head().style.set_properties(**{'background-color':'#f4c095','color':'black','border':'2.5px solid black'})
# Out:
# Head of the dataset:
# <style type="text/css">
# #T_f351a_row0_col0, #T_f351a_row0_col1, #T_f351a_row0_col2, #T_f351a_row0_col3, #T_f351a_row0_col4, #T_f351a_row0_col5, #T_f351a_row0_col6, #T_f351a_row0_col7, #T_f351a_row0_col8, #T_f351a_row0_col9, #T_f351a_row0_col10, #T_f351a_row0_col11, #T_f351a_row0_col12, #T_f351a_row0_col13, #T_f351a_row0_col14, #T_f351a_row0_col15, #T_f351a_row0_col16, #T_f351a_row0_col17, #T_f351a_row0_col18, #T_f351a_row0_col19, #T_f351a_row0_col20, #T_f351a_row1_col0, #T_f351a_row1_col1, #T_f351a_row1_col2, #T_f351a_row1_col3, #T_f351a_row1_col4, #T_f351a_row1_col5, #T_f351a_row1_col6, #T_f351a_row1_col7, #T_f351a_row1_col8, #T_f351a_row1_col9, #T_f351a_row1_col10, #T_f351a_row1_col11, #T_f351a_row1_col12, #T_f351a_row1_col13, #T_f351a_row1_col14, #T_f351a_row1_col15, #T_f351a_row1_col16, #T_f351a_row1_col17, #T_f351a_row1_col18, #T_f351a_row1_col19, #T_f351a_row1_col20, #T_f351a_row2_col0, #T_f351a_row2_col1, #T_f351a_row2_col2, #T_f351a_row2_col3, #T_f351a_row2_col4, #T_f351a_row2_col5, #T_f351a_row2_col6, #T_f351a_row2_col7, #T_f351a_row2_col8, #T_f351a_row2_col9, #T_f351a_row2_col10, #T_f351a_row2_col11, #T_f351a_row2_col12, #T_f351a_row2_col13, #T_f351a_row2_col14, #T_f351a_row2_col15, #T_f351a_row2_col16, #T_f351a_row2_col17, #T_f351a_row2_col18, #T_f351a_row2_col19, #T_f351a_row2_col20, #T_f351a_row3_col0, #T_f351a_row3_col1, #T_f351a_row3_col2, #T_f351a_row3_col3, #T_f351a_row3_col4, #T_f351a_row3_col5, #T_f351a_row3_col6, #T_f351a_row3_col7, #T_f351a_row3_col8, #T_f351a_row3_col9, #T_f351a_row3_col10, #T_f351a_row3_col11, #T_f351a_row3_col12, #T_f351a_row3_col13, #T_f351a_row3_col14, #T_f351a_row3_col15, #T_f351a_row3_col16, #T_f351a_row3_col17, #T_f351a_row3_col18, #T_f351a_row3_col19, #T_f351a_row3_col20, #T_f351a_row4_col0, #T_f351a_row4_col1, #T_f351a_row4_col2, #T_f351a_row4_col3, #T_f351a_row4_col4, #T_f351a_row4_col5, #T_f351a_row4_col6, #T_f351a_row4_col7, #T_f351a_row4_col8, #T_f351a_row4_col9, #T_f351a_row4_col10, #T_f351a_row4_col11, #T_f351a_row4_col12, #T_f351a_row4_col13, #T_f351a_row4_col14, #T_f351a_row4_col15, #T_f351a_row4_col16, #T_f351a_row4_col17, #T_f351a_row4_col18, #T_f351a_row4_col19, #T_f351a_row4_col20 {
#   background-color: #f4c095;
#   color: black;
#   border: 2.5px solid black;
# }
# </style>
# <table id="T_f351a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f351a_level0_col0" class="col_heading level0 col0" >customerID</th>
#       <th id="T_f351a_level0_col1" class="col_heading level0 col1" >gender</th>
#       <th id="T_f351a_level0_col2" class="col_heading level0 col2" >SeniorCitizen</th>
#       <th id="T_f351a_level0_col3" class="col_heading level0 col3" >Partner</th>
#       <th id="T_f351a_level0_col4" class="col_heading level0 col4" >Dependents</th>
#       <th id="T_f351a_level0_col5" class="col_heading level0 col5" >tenure</th>
#       <th id="T_f351a_level0_col6" class="col_heading level0 col6" >PhoneService</th>
#       <th id="T_f351a_level0_col7" class="col_heading level0 col7" >MultipleLines</th>
#       <th id="T_f351a_level0_col8" class="col_heading level0 col8" >InternetService</th>
#       <th id="T_f351a_level0_col9" class="col_heading level0 col9" >OnlineSecurity</th>
#       <th id="T_f351a_level0_col10" class="col_heading level0 col10" >OnlineBackup</th>
#       <th id="T_f351a_level0_col11" class="col_heading level0 col11" >DeviceProtection</th>
#       <th id="T_f351a_level0_col12" class="col_heading level0 col12" >TechSupport</th>
#       <th id="T_f351a_level0_col13" class="col_heading level0 col13" >StreamingTV</th>
#       <th id="T_f351a_level0_col14" class="col_heading level0 col14" >StreamingMovies</th>
#       <th id="T_f351a_level0_col15" class="col_heading level0 col15" >Contract</th>
#       <th id="T_f351a_level0_col16" class="col_heading level0 col16" >PaperlessBilling</th>
#       <th id="T_f351a_level0_col17" class="col_heading level0 col17" >PaymentMethod</th>
#       <th id="T_f351a_level0_col18" class="col_heading level0 col18" >MonthlyCharges</th>
#       <th id="T_f351a_level0_col19" class="col_heading level0 col19" >TotalCharges</th>
#       <th id="T_f351a_level0_col20" class="col_heading level0 col20" >Churn</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f351a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f351a_row0_col0" class="data row0 col0" >7590-VHVEG</td>
#       <td id="T_f351a_row0_col1" class="data row0 col1" >Female</td>
#       <td id="T_f351a_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_f351a_row0_col3" class="data row0 col3" >Yes</td>
#       <td id="T_f351a_row0_col4" class="data row0 col4" >No</td>
#       <td id="T_f351a_row0_col5" class="data row0 col5" >1</td>
#       <td id="T_f351a_row0_col6" class="data row0 col6" >No</td>
#       <td id="T_f351a_row0_col7" class="data row0 col7" >No phone service</td>
#       <td id="T_f351a_row0_col8" class="data row0 col8" >DSL</td>
#       <td id="T_f351a_row0_col9" class="data row0 col9" >No</td>
#       <td id="T_f351a_row0_col10" class="data row0 col10" >Yes</td>
#       <td id="T_f351a_row0_col11" class="data row0 col11" >No</td>
#       <td id="T_f351a_row0_col12" class="data row0 col12" >No</td>
#       <td id="T_f351a_row0_col13" class="data row0 col13" >No</td>
#       <td id="T_f351a_row0_col14" class="data row0 col14" >No</td>
#       <td id="T_f351a_row0_col15" class="data row0 col15" >Month-to-month</td>
#       <td id="T_f351a_row0_col16" class="data row0 col16" >Yes</td>
#       <td id="T_f351a_row0_col17" class="data row0 col17" >Electronic check</td>
#       <td id="T_f351a_row0_col18" class="data row0 col18" >29.850000</td>
#       <td id="T_f351a_row0_col19" class="data row0 col19" >29.85</td>
#       <td id="T_f351a_row0_col20" class="data row0 col20" >No</td>
#     </tr>
#     <tr>
#       <th id="T_f351a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f351a_row1_col0" class="data row1 col0" >5575-GNVDE</td>
#       <td id="T_f351a_row1_col1" class="data row1 col1" >Male</td>
#       <td id="T_f351a_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_f351a_row1_col3" class="data row1 col3" >No</td>
#       <td id="T_f351a_row1_col4" class="data row1 col4" >No</td>
#       <td id="T_f351a_row1_col5" class="data row1 col5" >34</td>
#       <td id="T_f351a_row1_col6" class="data row1 col6" >Yes</td>
#       <td id="T_f351a_row1_col7" class="data row1 col7" >No</td>
#       <td id="T_f351a_row1_col8" class="data row1 col8" >DSL</td>
#       <td id="T_f351a_row1_col9" class="data row1 col9" >Yes</td>
#       <td id="T_f351a_row1_col10" class="data row1 col10" >No</td>
#       <td id="T_f351a_row1_col11" class="data row1 col11" >Yes</td>
#       <td id="T_f351a_row1_col12" class="data row1 col12" >No</td>
#       <td id="T_f351a_row1_col13" class="data row1 col13" >No</td>
#       <td id="T_f351a_row1_col14" class="data row1 col14" >No</td>
#       <td id="T_f351a_row1_col15" class="data row1 col15" >One year</td>
#       <td id="T_f351a_row1_col16" class="data row1 col16" >No</td>
#       <td id="T_f351a_row1_col17" class="data row1 col17" >Mailed check</td>
#       <td id="T_f351a_row1_col18" class="data row1 col18" >56.950000</td>
#       <td id="T_f351a_row1_col19" class="data row1 col19" >1889.5</td>
#       <td id="T_f351a_row1_col20" class="data row1 col20" >No</td>
#     </tr>
#     <tr>
#       <th id="T_f351a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f351a_row2_col0" class="data row2 col0" >3668-QPYBK</td>
#       <td id="T_f351a_row2_col1" class="data row2 col1" >Male</td>
#       <td id="T_f351a_row2_col2" class="data row2 col2" >0</td>
#       <td id="T_f351a_row2_col3" class="data row2 col3" >No</td>
#       <td id="T_f351a_row2_col4" class="data row2 col4" >No</td>
#       <td id="T_f351a_row2_col5" class="data row2 col5" >2</td>
#       <td id="T_f351a_row2_col6" class="data row2 col6" >Yes</td>
#       <td id="T_f351a_row2_col7" class="data row2 col7" >No</td>
#       <td id="T_f351a_row2_col8" class="data row2 col8" >DSL</td>
#       <td id="T_f351a_row2_col9" class="data row2 col9" >Yes

# %%
# Display the last few rows of the dataset
print("Tail of the dataset:")
data.tail().style.set_properties(**{'background-color':'#f4c095','color':'black','border':'2.5px solid black'})
# Out:
# Tail of the dataset:
# <style type="text/css">
# #T_58013_row0_col0, #T_58013_row0_col1, #T_58013_row0_col2, #T_58013_row0_col3, #T_58013_row0_col4, #T_58013_row0_col5, #T_58013_row0_col6, #T_58013_row0_col7, #T_58013_row0_col8, #T_58013_row0_col9, #T_58013_row0_col10, #T_58013_row0_col11, #T_58013_row0_col12, #T_58013_row0_col13, #T_58013_row0_col14, #T_58013_row0_col15, #T_58013_row0_col16, #T_58013_row0_col17, #T_58013_row0_col18, #T_58013_row0_col19, #T_58013_row0_col20, #T_58013_row1_col0, #T_58013_row1_col1, #T_58013_row1_col2, #T_58013_row1_col3, #T_58013_row1_col4, #T_58013_row1_col5, #T_58013_row1_col6, #T_58013_row1_col7, #T_58013_row1_col8, #T_58013_row1_col9, #T_58013_row1_col10, #T_58013_row1_col11, #T_58013_row1_col12, #T_58013_row1_col13, #T_58013_row1_col14, #T_58013_row1_col15, #T_58013_row1_col16, #T_58013_row1_col17, #T_58013_row1_col18, #T_58013_row1_col19, #T_58013_row1_col20, #T_58013_row2_col0, #T_58013_row2_col1, #T_58013_row2_col2, #T_58013_row2_col3, #T_58013_row2_col4, #T_58013_row2_col5, #T_58013_row2_col6, #T_58013_row2_col7, #T_58013_row2_col8, #T_58013_row2_col9, #T_58013_row2_col10, #T_58013_row2_col11, #T_58013_row2_col12, #T_58013_row2_col13, #T_58013_row2_col14, #T_58013_row2_col15, #T_58013_row2_col16, #T_58013_row2_col17, #T_58013_row2_col18, #T_58013_row2_col19, #T_58013_row2_col20, #T_58013_row3_col0, #T_58013_row3_col1, #T_58013_row3_col2, #T_58013_row3_col3, #T_58013_row3_col4, #T_58013_row3_col5, #T_58013_row3_col6, #T_58013_row3_col7, #T_58013_row3_col8, #T_58013_row3_col9, #T_58013_row3_col10, #T_58013_row3_col11, #T_58013_row3_col12, #T_58013_row3_col13, #T_58013_row3_col14, #T_58013_row3_col15, #T_58013_row3_col16, #T_58013_row3_col17, #T_58013_row3_col18, #T_58013_row3_col19, #T_58013_row3_col20, #T_58013_row4_col0, #T_58013_row4_col1, #T_58013_row4_col2, #T_58013_row4_col3, #T_58013_row4_col4, #T_58013_row4_col5, #T_58013_row4_col6, #T_58013_row4_col7, #T_58013_row4_col8, #T_58013_row4_col9, #T_58013_row4_col10, #T_58013_row4_col11, #T_58013_row4_col12, #T_58013_row4_col13, #T_58013_row4_col14, #T_58013_row4_col15, #T_58013_row4_col16, #T_58013_row4_col17, #T_58013_row4_col18, #T_58013_row4_col19, #T_58013_row4_col20 {
#   background-color: #f4c095;
#   color: black;
#   border: 2.5px solid black;
# }
# </style>
# <table id="T_58013">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_58013_level0_col0" class="col_heading level0 col0" >customerID</th>
#       <th id="T_58013_level0_col1" class="col_heading level0 col1" >gender</th>
#       <th id="T_58013_level0_col2" class="col_heading level0 col2" >SeniorCitizen</th>
#       <th id="T_58013_level0_col3" class="col_heading level0 col3" >Partner</th>
#       <th id="T_58013_level0_col4" class="col_heading level0 col4" >Dependents</th>
#       <th id="T_58013_level0_col5" class="col_heading level0 col5" >tenure</th>
#       <th id="T_58013_level0_col6" class="col_heading level0 col6" >PhoneService</th>
#       <th id="T_58013_level0_col7" class="col_heading level0 col7" >MultipleLines</th>
#       <th id="T_58013_level0_col8" class="col_heading level0 col8" >InternetService</th>
#       <th id="T_58013_level0_col9" class="col_heading level0 col9" >OnlineSecurity</th>
#       <th id="T_58013_level0_col10" class="col_heading level0 col10" >OnlineBackup</th>
#       <th id="T_58013_level0_col11" class="col_heading level0 col11" >DeviceProtection</th>
#       <th id="T_58013_level0_col12" class="col_heading level0 col12" >TechSupport</th>
#       <th id="T_58013_level0_col13" class="col_heading level0 col13" >StreamingTV</th>
#       <th id="T_58013_level0_col14" class="col_heading level0 col14" >StreamingMovies</th>
#       <th id="T_58013_level0_col15" class="col_heading level0 col15" >Contract</th>
#       <th id="T_58013_level0_col16" class="col_heading level0 col16" >PaperlessBilling</th>
#       <th id="T_58013_level0_col17" class="col_heading level0 col17" >PaymentMethod</th>
#       <th id="T_58013_level0_col18" class="col_heading level0 col18" >MonthlyCharges</th>
#       <th id="T_58013_level0_col19" class="col_heading level0 col19" >TotalCharges</th>
#       <th id="T_58013_level0_col20" class="col_heading level0 col20" >Churn</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_58013_level0_row0" class="row_heading level0 row0" >7038</th>
#       <td id="T_58013_row0_col0" class="data row0 col0" >6840-RESVB</td>
#       <td id="T_58013_row0_col1" class="data row0 col1" >Male</td>
#       <td id="T_58013_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_58013_row0_col3" class="data row0 col3" >Yes</td>
#       <td id="T_58013_row0_col4" class="data row0 col4" >Yes</td>
#       <td id="T_58013_row0_col5" class="data row0 col5" >24</td>
#       <td id="T_58013_row0_col6" class="data row0 col6" >Yes</td>
#       <td id="T_58013_row0_col7" class="data row0 col7" >Yes</td>
#       <td id="T_58013_row0_col8" class="data row0 col8" >DSL</td>
#       <td id="T_58013_row0_col9" class="data row0 col9" >Yes</td>
#       <td id="T_58013_row0_col10" class="data row0 col10" >No</td>
#       <td id="T_58013_row0_col11" class="data row0 col11" >Yes</td>
#       <td id="T_58013_row0_col12" class="data row0 col12" >Yes</td>
#       <td id="T_58013_row0_col13" class="data row0 col13" >Yes</td>
#       <td id="T_58013_row0_col14" class="data row0 col14" >Yes</td>
#       <td id="T_58013_row0_col15" class="data row0 col15" >One year</td>
#       <td id="T_58013_row0_col16" class="data row0 col16" >Yes</td>
#       <td id="T_58013_row0_col17" class="data row0 col17" >Mailed check</td>
#       <td id="T_58013_row0_col18" class="data row0 col18" >84.800000</td>
#       <td id="T_58013_row0_col19" class="data row0 col19" >1990.5</td>
#       <td id="T_58013_row0_col20" class="data row0 col20" >No</td>
#     </tr>
#     <tr>
#       <th id="T_58013_level0_row1" class="row_heading level0 row1" >7039</th>
#       <td id="T_58013_row1_col0" class="data row1 col0" >2234-XADUH</td>
#       <td id="T_58013_row1_col1" class="data row1 col1" >Female</td>
#       <td id="T_58013_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_58013_row1_col3" class="data row1 col3" >Yes</td>
#       <td id="T_58013_row1_col4" class="data row1 col4" >Yes</td>
#       <td id="T_58013_row1_col5" class="data row1 col5" >72</td>
#       <td id="T_58013_row1_col6" class="data row1 col6" >Yes</td>
#       <td id="T_58013_row1_col7" class="data row1 col7" >Yes</td>
#       <td id="T_58013_row1_col8" class="data row1 col8" >Fiber optic</td>
#       <td id="T_58013_row1_col9" class="data row1 col9" >No</td>
#       <td id="T_58013_row1_col10" class="data row1 col10" >Yes</td>
#       <td id="T_58013_row1_col11" class="data row1 col11" >Yes</td>
#       <td id="T_58013_row1_col12" class="data row1 col12" >No</td>
#       <td id="T_58013_row1_col13" class="data row1 col13" >Yes</td>
#       <td id="T_58013_row1_col14" class="data row1 col14" >Yes</td>
#       <td id="T_58013_row1_col15" class="data row1 col15" >One year</td>
#       <td id="T_58013_row1_col16" class="data row1 col16" >Yes</td>
#       <td id="T_58013_row1_col17" class="data row1 col17" >Credit card (automatic)</td>
#       <td id="T_58013_row1_col18" class="data row1 col18" >103.200000</td>
#       <td id="T_58013_row1_col19" class="data row1 col19" >7362.9</td>
#       <td id="T_58013_row1_col20" class="data row1 col20" >No</td>
#     </tr>
#     <tr>
#       <th id="T_58013_level0_row2" class="row_heading level0 row2" >7040</th>
#       <td id="T_58013_row2_col0" class="data row2 col0" >4801-JZAZL</td>
#       <td id="T_58013_row2_col1" class="data row2 col1" >Female</td>
#       <td id="T_58013_row2_col2" class="data row2 col2" >0</td>
#       <td id="T_58013_row2_col3" class="data row2 col3" >Yes</td>
#       <td id="T_58013_row2_col4" class="data row2 col4" >Yes</td>
#       <td id="T_58013_row2_col5" class="data row2 col5" >11</td>
#       <td id="T_58013_row2_col6" class="data row2 col6" >No</td>
#       <td id="T_58013_row2_col7" class="data row2 col7" >No phone service</td>
#       <td id="T_58013_row2_col8" class="data row2 col8" >DSL</td>
#       <td id="T_58013_

# %%
# Number of records in the dataset
print('Number of records in the dataset:', len(data))

# Dimensions of the dataset (rows, columns)
print('Dimensions of the dataset:', data.shape)
# Out:
# Number of records in the dataset: 7043
# Dimensions of the dataset: (7043, 21)

# %%
# Display information about the dataset, including data types and non-null counts
print("Information about the dataset:")
print(data.info())
# Out:
# Information about the dataset:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
#  16  PaperlessBilling  7043 non-null   object
#  17  PaymentMethod     7043 non-null   object
#  18  MonthlyCharges    7043 non-null   float64
#  19  TotalCharges      7043 non-null   object
#  20  Churn             7043 non-null   object
# dtypes: float64(1), int64(2), object(18)
# memory usage: 1.1+ MB
# None

# %% [markdown]
# - There are no missing values in the dataset.

# %%
# Display summary statistics of the dataset
print("Summary statistics:")
data.describe().T.style.set_properties(**{'background-color':'#f4c095','color':'black','border':'2.5px solid black'})
# Out:
# Summary statistics:
# <style type="text/css">
# #T_8e680_row0_col0, #T_8e680_row0_col1, #T_8e680_row0_col2, #T_8e680_row0_col3, #T_8e680_row0_col4, #T_8e680_row0_col5, #T_8e680_row0_col6, #T_8e680_row0_col7, #T_8e680_row1_col0, #T_8e680_row1_col1, #T_8e680_row1_col2, #T_8e680_row1_col3, #T_8e680_row1_col4, #T_8e680_row1_col5, #T_8e680_row1_col6, #T_8e680_row1_col7, #T_8e680_row2_col0, #T_8e680_row2_col1, #T_8e680_row2_col2, #T_8e680_row2_col3, #T_8e680_row2_col4, #T_8e680_row2_col5, #T_8e680_row2_col6, #T_8e680_row2_col7 {
#   background-color: #f4c095;
#   color: black;
#   border: 2.5px solid black;
# }
# </style>
# <table id="T_8e680">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8e680_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_8e680_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_8e680_level0_col2" class="col_heading level0 col2" >std</th>
#       <th id="T_8e680_level0_col3" class="col_heading level0 col3" >min</th>
#       <th id="T_8e680_level0_col4" class="col_heading level0 col4" >25%</th>
#       <th id="T_8e680_level0_col5" class="col_heading level0 col5" >50%</th>
#       <th id="T_8e680_level0_col6" class="col_heading level0 col6" >75%</th>
#       <th id="T_8e680_level0_col7" class="col_heading level0 col7" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8e680_level0_row0" class="row_heading level0 row0" >SeniorCitizen</th>
#       <td id="T_8e680_row0_col0" class="data row0 col0" >7043.000000</td>
#       <td id="T_8e680_row0_col1" class="data row0 col1" >0.162147</td>
#       <td id="T_8e680_row0_col2" class="data row0 col2" >0.368612</td>
#       <td id="T_8e680_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_8e680_row0_col4" class="data row0 col4" >0.000000</td>
#       <td id="T_8e680_row0_col5" class="data row0 col5" >0.000000</td>
#       <td id="T_8e680_row0_col6" class="data row0 col6" >0.000000</td>
#       <td id="T_8e680_row0_col7" class="data row0 col7" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_8e680_level0_row1" class="row_heading level0 row1" >tenure</th>
#       <td id="T_8e680_row1_col0" class="data row1 col0" >7043.000000</td>
#       <td id="T_8e680_row1_col1" class="data row1 col1" >32.371149</td>
#       <td id="T_8e680_row1_col2" class="data row1 col2" >24.559481</td>
#       <td id="T_8e680_row1_col3" class="data row1 col3" >0.000000</td>
#       <td id="T_8e680_row1_col4" class="data row1 col4" >9.000000</td>
#       <td id="T_8e680_row1_col5" class="data row1 col5" >29.000000</td>
#       <td id="T_8e680_row1_col6" class="data row1 col6" >55.000000</td>
#       <td id="T_8e680_row1_col7" class="data row1 col7" >72.000000</td>
#     </tr>
#     <tr>
#       <th id="T_8e680_level0_row2" class="row_heading level0 row2" >MonthlyCharges</th>
#       <td id="T_8e680_row2_col0" class="data row2 col0" >7043.000000</td>
#       <td id="T_8e680_row2_col1" class="data row2 col1" >64.761692</td>
#       <td id="T_8e680_row2_col2" class="data row2 col2" >30.090047</td>
#       <td id="T_8e680_row2_col3" class="data row2 col3" >18.250000</td>
#       <td id="T_8e680_row2_col4" class="data row2 col4" >35.500000</td>
#       <td id="T_8e680_row2_col5" class="data row2 col5" >70.350000</td>
#       <td id="T_8e680_row2_col6" class="data row2 col6" >89.850000</td>
#       <td id="T_8e680_row2_col7" class="data row2 col7" >118.750000</td>
#     </tr>
#   </tbody>
# </table>

# %%
data.columns.values
# Out:
# array(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
#        'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract',
#        'PaperlessBilling', 'PaymentMethod', 'MonthlyCharges',
#        'TotalCharges', 'Churn'], dtype=object)

# %%
# Dropping Customer ID column
data.drop('customerID',axis=1,inplace=True)

# %%
# Value Counts for each column
value_counts_gender = data['gender'].value_counts()
value_counts_senior_citizen = data['SeniorCitizen'].value_counts()
value_counts_partner = data['Partner'].value_counts()
value_counts_dependents = data['Dependents'].value_counts()
value_counts_phone_service = data['PhoneService'].value_counts()
value_counts_multiple_lines = data['MultipleLines'].value_counts()
value_counts_internet_service = data['InternetService'].value_counts()
value_counts_online_security = data['OnlineSecurity'].value_counts()
value_counts_online_backup = data['OnlineBackup'].value_counts()
value_counts_device_protection = data['DeviceProtection'].value_counts()
value_counts_tech_support = data['TechSupport'].value_counts()
value_counts_streaming_tv = data['StreamingTV'].value_counts()
value_counts_streaming_movies = data['StreamingMovies'].value_counts()
value_counts_contract = data['Contract'].value_counts()
value_counts_paperless_billing = data['PaperlessBilling'].value_counts()
value_counts_payment_method = data['PaymentMethod'].value_counts()
value_counts_churn = data['Churn'].value_counts()

# Display value counts for each column
print("Gender:")
print(value_counts_gender)

print("\nSeniorCitizen:")
print(value_counts_senior_citizen)

print("\nPartner:")
print(value_counts_partner)

print("\nDependents:")
print(value_counts_dependents)

print("\nPhoneService:")
print(value_counts_phone_service)

print("\nMultipleLines:")
print(value_counts_multiple_lines)

print("\nInternetService:")
print(value_counts_internet_service)

print("\nOnlineSecurity:")
print(value_counts_online_security)

print("\nOnlineBackup:")
print(value_counts_online_backup)

print("\nDeviceProtection:")
print(value_counts_device_protection)

print("\nTechSupport:")
print(value_counts_tech_support)

print("\nStreamingTV:")
print(value_counts_streaming_tv)

print("\nStreamingMovies:")
print(value_counts_streaming_movies)

print("\nContract:")
print(value_counts_contract)

print("\nPaperlessBilling:")
print(value_counts_paperless_billing)

print("\nPaymentMethod:")
print(value_counts_payment_method)

print("\nChurn:")
print(value_counts_churn)
# Out:
# Gender:
# Male      3555
# Female    3488
# Name: gender, dtype: int64
#
# SeniorCitizen:
# 0    5901
# 1    1142
# Name: SeniorCitizen, dtype: int64
#
# Partner:
# No     3641
# Yes    3402
# Name: Partner, dtype: int64
#
# Dependents:
# No     4933
# Yes    2110
# Name: Dependents, dtype: int64
#
# PhoneService:
# Yes    6361
# No      682
# Name: PhoneService, dtype: int64
#
# MultipleLines:
# No                  3390
# Yes                 2971
# No phone service     682
# Name: MultipleLines, dtype: int64
#
# InternetService:
# Fiber optic    3096
# DSL            2421
# No             1526
# Name: InternetService, dtype: int64
#
# OnlineSecurity:
# No                     3498
# Yes                    2019
# No internet service    1526
# Name: OnlineSecurity, dtype: int64
#
# OnlineBackup:
# No                     3088
# Yes                    2429
# No internet service    1526
# Name: OnlineBackup, dtype: int64
#
# DeviceProtection:
# No                     3095
# Yes                    2422
# No internet service    1526
# Name: DeviceProtection, dtype: int64
#
# TechSupport:
# No                     3473
# Yes                    2044
# No internet service    1526
# Name: TechSupport, dtype: int64
#
# StreamingTV:
# No                     2810
# Yes                    2707
# No internet service    1526
# Name: StreamingTV, dtype: int64
#
# StreamingMovies:
# No                     2785
# Yes                    2732
# No internet service    1526
# Name: StreamingMovies, dtype: int64
#
# Contract:
# Month-to-month    3875
# Two year          1695
# One year          1473
# Name: Contract, dtype: int64
#
# PaperlessBilling:
# Yes    4171
# No     2872
# Name: PaperlessBilling, dtype: int64
#
# PaymentMethod:
# Electronic check             2365
# Mailed check                 1612
# Bank transfer (automatic)    1544
# Credit card (automatic)      1522
# Name: PaymentMethod, dtype: int64
#
# Churn:
# No     5174
# Yes    1869
# Name: Churn, dtype: int64

# %%
#setting custom palette
sns.set_style("white")
sns.set_context("poster",font_scale = .7)

palette = ["#007f7b", "#6ab097", "#f2aa86", "#e7353b", "#ffa26e", "#b09e6d", "#ff7000", "#c11528",
           "#b20323", "#cfcfcf", "#ffeb3e", "#ffd700", "#424542", "#252525"]

# %%
# Creating the count plot
plt.figure(figsize=(20, 8)) 
ax = sns.countplot(x='gender', hue='Churn', data=data, palette=palette[0:])

# Adding labels and title
plt.xlabel("Gender")
plt.ylabel("Count")
plt.title("Gender vs. Churn")

# Calculating the count for each category
total = len(data)
for p in ax.patches:
    count = p.get_height()
    x = p.get_x() + p.get_width() / 2
    y = p.get_height()
    ax.text(x, y, f'{count}', ha='center', va='bottom')

# Displaying the count plot
plt.legend(title="Churn", loc='upper right', labels=['No', 'Yes'])
plt.show()

# %% [markdown]
# - After analyzing the relationship between gender and chrun, We can see that **there is not much difference in churn rates between both gender**, It shows similar proportions of customer churned in both gender category.

# %%
#  Creating the count plot
plt.figure(figsize=(20, 8))  
ax = sns.countplot(x='Contract', hue='Churn', data=data, palette=palette[2:])

# Adding labels and title
plt.xlabel("Contract")
plt.ylabel("Count")
plt.title("Contract vs. Churn")

# Calculating the count for each category
total = len(data)
for p in ax.patches:
    count = p.get_height()
    x = p.get_x() + p.get_width() / 2
    y = p.get_height()
    ax.text(x, y, f'{count}', ha='center', va='bottom')

# Displaying the count plot
plt.legend(title="Churn", loc='upper right', labels=['No', 'Yes'])
plt.show()

# %% [markdown]
# - After analyzing the contract and churn features, We can easily say that **there is huge difference in churn rates based on contract.**

# %%
# Filter the data for churned customers
churned_data = data[data['Churn'] == 'Yes']
# Create the histogram
plt.figure(figsize=(20, 8))
sns.histplot(data=churned_data, x='tenure', bins='auto', color=palette[4])

# Adding labels and title
plt.xlabel("Tenure (Months)")
plt.ylabel("Count")
plt.title("Tenure of Churned Customers")

# Displaying the plot
plt.show()

# %%
# Creating the stacked bar plot
plt.figure(figsize=(20, 8))  
sns.countplot(data=data, x='Partner', hue='Churn', palette=palette[5:])

# Adding labels and title
plt.xlabel("Partner")
plt.ylabel("Count")
plt.title("Churn by Partner Status")

# Displaying the plot
plt.legend(title="Churn", loc='upper right', labels=['No', 'Yes'])
plt.show()

# %%
# Creating the stacked bar plot
plt.figure(figsize=(20, 8))
sns.countplot(data=data, x='PaymentMethod', hue='Churn', palette=palette[8:])

# Adding labels and title
plt.xlabel("Payment Method")
plt.ylabel("Count")
plt.title("Churn by Payment Method")

# Displaying the plot
plt.legend(title="Churn", loc='upper right', labels=['No', 'Yes'])
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.tight_layout()  # To prevent overlapping labels
plt.show()

# %%
# Creating the count plot
plt.figure(figsize=(20,8))  
sns.countplot(x='PhoneService', hue='Churn', data=data, palette=palette[10:])

# Adding labels and title
plt.xlabel("Phone Service")
plt.ylabel("Count")
plt.title("Phone Service vs. Churn")

# Displaying the plot
plt.legend(title="Churn", loc='upper right', labels=['No', 'Yes'])
plt.show()

# %%
# Creating the count plot
plt.figure(figsize=(20, 8))  
sns.countplot(x='PaperlessBilling', hue='Churn', data=data, palette=palette[11:])

# Adding labels and title
plt.xlabel("Paperless Billing")
plt.ylabel("Count")
plt.title("Paperless Billing vs. Churn")

# Displaying the plot
plt.legend(title="Churn", loc='upper right', labels=['No', 'Yes'])
plt.show()

# %%
# Creating the histogram
plt.figure(figsize=(20, 8))
sns.histplot(data['MonthlyCharges'], bins='auto', kde=True, color=palette[1])

# Adding labels and title
plt.xlabel("Monthly Charges")
plt.ylabel("Frequency")
plt.title("Distribution of Monthly Charges")

# Displaying the plot
plt.show()

# %%
#  Converting TotalCharges column into float values from object 
data['TotalCharges']=pd.to_numeric(data['TotalCharges'], errors='coerce')

# %%
# Identifying columns with exactly two unique values ('No' and 'Yes')
two_value_cols = [col for col in data.columns if data[col].nunique() == 2]

# Creating a dictionary to map 'No' to 0 and 'Yes' to 1
replace_dict = {'No': 0, 'Yes': 1}

# Converting categorical values with two unique values in the identified columns to numeric
for col in two_value_cols:
    data[col] = data[col].replace(replace_dict)

# %%
# Creatating a second dictionary to map the values to their respective replacements
replace_dict2 = {'No internet service': 0, 'No': 1, 'Yes': 2}

# Replace the values in the column using the dictionary
data['OnlineSecurity'] = data['OnlineSecurity'].replace(replace_dict2)
data['OnlineBackup'] = data['OnlineBackup'].replace(replace_dict2)
data['DeviceProtection'] = data['DeviceProtection'].replace(replace_dict2)
data['TechSupport'] = data['TechSupport'].replace(replace_dict2)
data['StreamingTV'] = data['StreamingTV'].replace(replace_dict2)
data['StreamingMovies'] = data['StreamingMovies'].replace(replace_dict2)

# %%
# Replacing the values in MultipleLines and Contract Column
data['MultipleLines']=data['MultipleLines'].replace({'No phone service':0, 'No':1, 'Yes':2})
data['InternetService']=data['InternetService'].replace({'No':0, 'DSL':1, 'Fiber optic':2})
data['Contract']=data['Contract'].replace({'Month-to-month':0, 'One year':1, 'Two year':2})

# %%
# Performing one-hot encoding on 'PaymentMethod' and 'gender' columns
data = pd.get_dummies(data, columns=['gender','PaymentMethod'], drop_first=False)

# %%
print('Quick View at the dataset after pre-processing')

data.head(10).style.set_properties(**{'background-color':'#f4c095','color':'black','border':'2.5px solid black'})
# Out:
# Quick View at the dataset after pre-processing
# <style type="text/css">
# #T_20ac4_row0_col0, #T_20ac4_row0_col1, #T_20ac4_row0_col2, #T_20ac4_row0_col3, #T_20ac4_row0_col4, #T_20ac4_row0_col5, #T_20ac4_row0_col6, #T_20ac4_row0_col7, #T_20ac4_row0_col8, #T_20ac4_row0_col9, #T_20ac4_row0_col10, #T_20ac4_row0_col11, #T_20ac4_row0_col12, #T_20ac4_row0_col13, #T_20ac4_row0_col14, #T_20ac4_row0_col15, #T_20ac4_row0_col16, #T_20ac4_row0_col17, #T_20ac4_row0_col18, #T_20ac4_row0_col19, #T_20ac4_row0_col20, #T_20ac4_row0_col21, #T_20ac4_row0_col22, #T_20ac4_row0_col23, #T_20ac4_row1_col0, #T_20ac4_row1_col1, #T_20ac4_row1_col2, #T_20ac4_row1_col3, #T_20ac4_row1_col4, #T_20ac4_row1_col5, #T_20ac4_row1_col6, #T_20ac4_row1_col7, #T_20ac4_row1_col8, #T_20ac4_row1_col9, #T_20ac4_row1_col10, #T_20ac4_row1_col11, #T_20ac4_row1_col12, #T_20ac4_row1_col13, #T_20ac4_row1_col14, #T_20ac4_row1_col15, #T_20ac4_row1_col16, #T_20ac4_row1_col17, #T_20ac4_row1_col18, #T_20ac4_row1_col19, #T_20ac4_row1_col20, #T_20ac4_row1_col21, #T_20ac4_row1_col22, #T_20ac4_row1_col23, #T_20ac4_row2_col0, #T_20ac4_row2_col1, #T_20ac4_row2_col2, #T_20ac4_row2_col3, #T_20ac4_row2_col4, #T_20ac4_row2_col5, #T_20ac4_row2_col6, #T_20ac4_row2_col7, #T_20ac4_row2_col8, #T_20ac4_row2_col9, #T_20ac4_row2_col10, #T_20ac4_row2_col11, #T_20ac4_row2_col12, #T_20ac4_row2_col13, #T_20ac4_row2_col14, #T_20ac4_row2_col15, #T_20ac4_row2_col16, #T_20ac4_row2_col17, #T_20ac4_row2_col18, #T_20ac4_row2_col19, #T_20ac4_row2_col20, #T_20ac4_row2_col21, #T_20ac4_row2_col22, #T_20ac4_row2_col23, #T_20ac4_row3_col0, #T_20ac4_row3_col1, #T_20ac4_row3_col2, #T_20ac4_row3_col3, #T_20ac4_row3_col4, #T_20ac4_row3_col5, #T_20ac4_row3_col6, #T_20ac4_row3_col7, #T_20ac4_row3_col8, #T_20ac4_row3_col9, #T_20ac4_row3_col10, #T_20ac4_row3_col11, #T_20ac4_row3_col12, #T_20ac4_row3_col13, #T_20ac4_row3_col14, #T_20ac4_row3_col15, #T_20ac4_row3_col16, #T_20ac4_row3_col17, #T_20ac4_row3_col18, #T_20ac4_row3_col19, #T_20ac4_row3_col20, #T_20ac4_row3_col21, #T_20ac4_row3_col22, #T_20ac4_row3_col23, #T_20ac4_row4_col0, #T_20ac4_row4_col1, #T_20ac4_row4_col2, #T_20ac4_row4_col3, #T_20ac4_row4_col4, #T_20ac4_row4_col5, #T_20ac4_row4_col6, #T_20ac4_row4_col7, #T_20ac4_row4_col8, #T_20ac4_row4_col9, #T_20ac4_row4_col10, #T_20ac4_row4_col11, #T_20ac4_row4_col12, #T_20ac4_row4_col13, #T_20ac4_row4_col14, #T_20ac4_row4_col15, #T_20ac4_row4_col16, #T_20ac4_row4_col17, #T_20ac4_row4_col18, #T_20ac4_row4_col19, #T_20ac4_row4_col20, #T_20ac4_row4_col21, #T_20ac4_row4_col22, #T_20ac4_row4_col23, #T_20ac4_row5_col0, #T_20ac4_row5_col1, #T_20ac4_row5_col2, #T_20ac4_row5_col3, #T_20ac4_row5_col4, #T_20ac4_row5_col5, #T_20ac4_row5_col6, #T_20ac4_row5_col7, #T_20ac4_row5_col8, #T_20ac4_row5_col9, #T_20ac4_row5_col10, #T_20ac4_row5_col11, #T_20ac4_row5_col12, #T_20ac4_row5_col13, #T_20ac4_row5_col14, #T_20ac4_row5_col15, #T_20ac4_row5_col16, #T_20ac4_row5_col17, #T_20ac4_row5_col18, #T_20ac4_row5_col19, #T_20ac4_row5_col20, #T_20ac4_row5_col21, #T_20ac4_row5_col22, #T_20ac4_row5_col23, #T_20ac4_row6_col0, #T_20ac4_row6_col1, #T_20ac4_row6_col2, #T_20ac4_row6_col3, #T_20ac4_row6_col4, #T_20ac4_row6_col5, #T_20ac4_row6_col6, #T_20ac4_row6_col7, #T_20ac4_row6_col8, #T_20ac4_row6_col9, #T_20ac4_row6_col10, #T_20ac4_row6_col11, #T_20ac4_row6_col12, #T_20ac4_row6_col13, #T_20ac4_row6_col14, #T_20ac4_row6_col15, #T_20ac4_row6_col16, #T_20ac4_row6_col17, #T_20ac4_row6_col18, #T_20ac4_row6_col19, #T_20ac4_row6_col20, #T_20ac4_row6_col21, #T_20ac4_row6_col22, #T_20ac4_row6_col23, #T_20ac4_row7_col0, #T_20ac4_row7_col1, #T_20ac4_row7_col2, #T_20ac4_row7_col3, #T_20ac4_row7_col4, #T_20ac4_row7_col5, #T_20ac4_row7_col6, #T_20ac4_row7_col7, #T_20ac4_row7_col8, #T_20ac4_row7_col9, #T_20ac4_row7_col10, #T_20ac4_row7_col11, #T_20ac4_row7_col12, #T_20ac4_row7_col13, #T_20ac4_row7_col14, #T_20ac4_row7_col15, #T_20ac4_row7_col16, #T_20ac4_row7_col17, #T_20ac4_row7_col18, #T_20ac4_row7_col19, #T_20ac4_row7_col20, #T_20ac4_row7_col21, #T_20ac4_row7_col22, #T_20ac4_row7_col23, #T_20ac4_row8_col0, #T_20ac4_row8_col1, #T_20ac4 ...
#   background-color: #f4c095;
#   color: black;
#   border: 2.5px solid black;
# }
# </style>
# <table id="T_20ac4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_20ac4_level0_col0" class="col_heading level0 col0" >SeniorCitizen</th>
#       <th id="T_20ac4_level0_col1" class="col_heading level0 col1" >Partner</th>
#       <th id="T_20ac4_level0_col2" class="col_heading level0 col2" >Dependents</th>
#       <th id="T_20ac4_level0_col3" class="col_heading level0 col3" >tenure</th>
#       <th id="T_20ac4_level0_col4" class="col_heading level0 col4" >PhoneService</th>
#       <th id="T_20ac4_level0_col5" class="col_heading level0 col5" >MultipleLines</th>
#       <th id="T_20ac4_level0_col6" class="col_heading level0 col6" >InternetService</th>
#       <th id="T_20ac4_level0_col7" class="col_heading level0 col7" >OnlineSecurity</th>
#       <th id="T_20ac4_level0_col8" class="col_heading level0 col8" >OnlineBackup</th>
#       <th id="T_20ac4_level0_col9" class="col_heading level0 col9" >DeviceProtection</th>
#       <th id="T_20ac4_level0_col10" class="col_heading level0 col10" >TechSupport</th>
#       <th id="T_20ac4_level0_col11" class="col_heading level0 col11" >StreamingTV</th>
#       <th id="T_20ac4_level0_col12" class="col_heading level0 col12" >StreamingMovies</th>
#       <th id="T_20ac4_level0_col13" class="col_heading level0 col13" >Contract</th>
#       <th id="T_20ac4_level0_col14" class="col_heading level0 col14" >PaperlessBilling</th>
#       <th id="T_20ac4_level0_col15" class="col_heading level0 col15" >MonthlyCharges</th>
#       <th id="T_20ac4_level0_col16" class="col_heading level0 col16" >TotalCharges</th>
#       <th id="T_20ac4_level0_col17" class="col_heading level0 col17" >Churn</th>
#       <th id="T_20ac4_level0_col18" class="col_heading level0 col18" >gender_Female</th>
#       <th id="T_20ac4_level0_col19" class="col_heading level0 col19" >gender_Male</th>
#       <th id="T_20ac4_level0_col20" class="col_heading level0 col20" >PaymentMethod_Bank transfer (automatic)</th>
#       <th id="T_20ac4_level0_col21" class="col_heading level0 col21" >PaymentMethod_Credit card (automatic)</th>
#       <th id="T_20ac4_level0_col22" class="col_heading level0 col22" >PaymentMethod_Electronic check</th>
#       <th id="T_20ac4_level0_col23" class="col_heading level0 col23" >PaymentMethod_Mailed check</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_20ac4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_20ac4_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_20ac4_row0_col1" class="data row0 col1" >1</td>
#       <td id="T_20ac4_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_20ac4_row0_col3" class="data row0 col3" >1</td>
#       <td id="T_20ac4_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_20ac4_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_20ac4_row0_col6" class="data row0 col6" >1</td>
#       <td id="T_20ac4_row0_col7" class="data row0 col7" >1</td>
#       <td id="T_20ac4_row0_col8" class="data row0 col8" >2</td>
